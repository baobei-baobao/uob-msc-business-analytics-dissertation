# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import collections

# %%
import torch
import random
from scipy.special import softmax
from sklearn.utils.class_weight import compute_class_weight
from datasets import Dataset
from sklearn.metrics import f1_score

import os
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

from sklearn.model_selection import train_test_split
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments,
    EarlyStoppingCallback
)

# %% [markdown]
# # **1st Model Test**

# %%
# Load data
df_pattaya = pd.read_csv('clean_pattaya.csv', encoding='utf-8')
df_pattaya_sen = df_pattaya[['processed_text']].dropna()

# Load model
def load_model(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    return tokenizer, model

# Compute sentiment probabilities
def sentiment_score(text, tokenizer, model):
    tokens = tokenizer(text, truncation=True, padding=True, max_length=512, return_tensors="pt")
    with torch.no_grad():
        logits = model(**tokens).logits
    return softmax(logits.numpy()[0])  # Returns [negative, neutral, positive]

# Convert probabilities to weighted sentiment intensity score
def intensity_score(probs):
    weights = [-1, 0, 1]  # Corresponding to [negative, neutral, positive]
    return round(sum(p * w for p, w in zip(probs, weights)), 3)

# Run sentiment analysis
models = {
    "RoBERTa": "cardiffnlp/twitter-roberta-base-sentiment"
}

for model_name, model_path in models.items():
    print(f"\nUsing model: {model_name}")
    tokenizer, model = load_model(model_path)

    # Apply sentiment scoring
    df_pattaya_sen['score_' + model_name] = df_pattaya_sen['processed_text'].apply(
        lambda x: sentiment_score(x, tokenizer, model)
    )

    # Apply intensity scoring
    df_pattaya_sen['intensity_' + model_name] = df_pattaya_sen['score_' + model_name].apply(intensity_score)

# %%
# convert scoreRoBERTa and scoreDistilBERT column into 2 other columns
df_pattaya_sen['resultRoBERTa'] = df_pattaya_sen['score_RoBERTa'].apply(lambda x: x.argmax())

# scoreRoBERTa will be resultRoBERTa with the max value being negative, neutral and positive according to their position
df_pattaya_sen['resultRoBERTa'] = df_pattaya_sen['resultRoBERTa'].replace({0: 'Negative', 1: 'Neutral', 2: 'Positive'})

df_pattaya_sen

# %%
# Merge on 'processed_text'
df_pattaya_cleaned = df_pattaya_sen.merge(
    df_pattaya[['processed_text', 'rating', 'date', 'travel_type', 'location']],  # choose columns to bring in
    on='processed_text',
    how='left'
)
df_pattaya_cleaned

# %%
df_pattaya_cleaned.to_csv('pattaya_sentiment.csv', index=False)

# %% [markdown]
# # **RoBERTa Enhancement**

# %%
df_pattaya = pd.read_csv('pattaya_sentiment.csv', encoding='utf-8')

# %%
# Encode labels
label_map = {'Negative': 0, 'Neutral': 1, 'Positive': 2}
df_pattaya['label_encoded'] = df_pattaya['resultRoBERTa'].map(label_map)

# Compute class weights
class_weights = compute_class_weight(class_weight='balanced', classes=np.array([0,1,2]), y=df_pattaya['label_encoded'])
weights_tensor = torch.tensor(class_weights, dtype=torch.float)

# %%
# Set random seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Load tokenizer and model
model_name = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=3)

# Tokenize function
def tokenize_function(examples):
    return tokenizer(examples["processed_text"], padding="max_length", truncation=True, max_length=128)

# Convert DataFrame to HuggingFace Dataset
dataset = Dataset.from_pandas(df_pattaya)
dataset = dataset.rename_column("label_encoded", "labels")
dataset = dataset.map(tokenize_function, batched=True)
dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])

# Train/Test Split
train_test = dataset.train_test_split(test_size=0.2, seed=seed)
train_dataset = train_test["train"]
eval_dataset = train_test["test"]

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    learning_rate=2e-5,
    seed=seed,
    load_best_model_at_end=True,
    metric_for_best_model="macro_f1",
    greater_is_better=True
)

# Custom loss function with class weights
def compute_loss(model, inputs, return_outputs=False, num_items_in_batch=0):
    labels = inputs.get("labels")
    outputs = model(**inputs)
    logits = outputs.get("logits")
    loss_fct = torch.nn.CrossEntropyLoss(weight=weights_tensor.to(logits.device))
    loss = loss_fct(logits, labels)
    return (loss, outputs) if return_outputs else loss

# Evaluation metric
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    macro_f1 = f1_score(labels, preds, average='macro')
    return {"macro_f1": macro_f1}

# Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=2)],
    # compute_loss_func=compute_loss
)

# Train the model
trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: kg24543 (kg24543-university-of-bristol) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250820_162407-2px93rqb</code>
# Syncing run <strong><a href='https://wandb.ai/kg24543-university-of-bristol/huggingface/runs/2px93rqb' target="_blank">fragrant-gorge-1</a></strong> to <a href='https://wandb.ai/kg24543-university-of-bristol/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kg24543-university-of-bristol/huggingface' target="_blank">https://wandb.ai/kg24543-university-of-bristol/huggingface</a>
#  View run at <a href='https://wandb.ai/kg24543-university-of-bristol/huggingface/runs/2px93rqb' target="_blank">https://wandb.ai/kg24543-university-of-bristol/huggingface/runs/2px93rqb</a>
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 20:41, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Macro F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.140443</td>
#       <td>0.794595</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.092955</td>
#       <td>0.780309</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# TrainOutput(global_step=50, training_loss=0.08690813064575195, metrics={'train_runtime': 1529.2847, 'train_samples_per_second': 0.523, 'train_steps_per_second': 0.033, 'total_flos': 52622683545600.0, 'train_loss': 0.08690813064575195, 'epoch': 2.0})

# %% [markdown]
# Key - a42eb9bc954e96d4d958b9cacfadb39921dead98

# %%
# Save the trained model
model_path = "./roberta_finetune_model"
trainer.save_model(model_path)
tokenizer.save_pretrained(model_path)

print(f"Model saved to: {model_path}")
# Out:
# Model saved to: ./roberta_finetune_model

# %% [markdown]
# **Pattaya Fitting**

# %%
# Load new data
df_pattaya = pd.read_csv('clean_pattaya.csv', encoding='utf-8')
df_pattaya_sen = df_pattaya[['processed_text']].dropna()

# %%
# Load fine-tuned model and tokenizer
model_path = "./roberta_finetune_model"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)

# Compute sentiment probabilities
def sentiment_score(text, tokenizer, model):
    tokens = tokenizer(text, truncation=True, padding=True, max_length=512, return_tensors="pt")
    with torch.no_grad():
        logits = model(**tokens).logits
    return softmax(logits.numpy()[0])  # Returns [negative, neutral, positive]

# Convert probabilities to weighted sentiment intensity score
def intensity_score(probs):
    weights = [-1, 0, 1]  # Corresponding to [negative, neutral, positive]
    return round(sum(p * w for p, w in zip(probs, weights)), 3)

# Apply sentiment scoring
df_pattaya_sen['score_RoBERTa'] = df_pattaya_sen['processed_text'].apply(
    lambda x: sentiment_score(x, tokenizer, model)
)

# Apply intensity scoring
df_pattaya_sen['intensity_RoBERTa'] = df_pattaya_sen['score_RoBERTa'].apply(intensity_score)

# %%
# convert scoreRoBERTa column into 2 other columns
df_pattaya_sen['resultRoBERTa'] = df_pattaya_sen['score_RoBERTa'].apply(lambda x: x.argmax())

# scoreRoBERTa will be resultRoBERTa with the max value being negative, neutral and positive according to their position
df_pattaya_sen['resultRoBERTa'] = df_pattaya_sen['resultRoBERTa'].replace({0: 'Negative', 1: 'Neutral', 2: 'Positive'})

df_pattaya_sen
# Out:
#                                          processed_text  \
# 0     best massage existence absolutely fabulous mas...
# 1     great place gem gallery pattaya amazing place ...
# 2     recommend place beautiful organized people wor...
# 3     life altering massage experience absolutely in...
# 4     finally relaxed rejuvenated friend got massage...
# ...                                                 ...
# 2333  great day well run water park start finish wen...
# 2334  awesome beach beach go ever restaurant bar lun...
# 2335  rainbow beach must go look rainbow beach jomti...
# 2336  beautiful building come animal rowing boat san...
# 2337  awful absolutely terrible run absolute rip ple...
#
#                                    score_RoBERTa  intensity_RoBERTa  \
# 0        [0.000545775, 0.0006527193, 0.99880147]              0.998
# 1      [0.00043520975, 0.0006707744, 0.99889404]              0.998
# 2       [0.00041371837, 0.0007984634, 0.9987878]              0.998
# 3      [0.00044122155, 0.0008386694, 0.99872017]              0.998
# 4       [0.0005455051, 0.00066375395, 0.9987908]              0.998
# ...                                          ...                ...
# 2333     [0.00052692054, 0.000617436, 0.9988556]              0.998
# 2334    [0.00031094882, 0.0017167189, 0.9979723]              0.998
# 2335  [0.00043922983, 0.00066251185, 0.99889827]              0.998
# 2336   [0.00027121327, 0.0014958514, 0.99823296]              0.998
# 2337       [0.9685624, 0.028818455, 0.002619132]             -0.966
#
#      resultRoBERTa
# 0         Positive
# 1         Positive
# 2         Positive
# 3         Positive
# 4         Positive
# ...            ...
# 2333      Positive
# 2334      Positive
# 2335      Positive
# 2336      Positive
# 2337      Negative
#
# [2338 rows x 4 columns]

# %%
# Merge on 'processed_text'
df_pattaya_cleaned = df_pattaya_sen.merge(
    df_pattaya[['processed_text', 'rating', 'date', 'travel_type', 'location']],  # choose columns to bring in
    on='processed_text',
    how='left'
)
df_pattaya_cleaned
# Out:
#                                          processed_text  \
# 0     best massage existence absolutely fabulous mas...
# 1     great place gem gallery pattaya amazing place ...
# 2     recommend place beautiful organized people wor...
# 3     life altering massage experience absolutely in...
# 4     finally relaxed rejuvenated friend got massage...
# ...                                                 ...
# 2333  great day well run water park start finish wen...
# 2334  awesome beach beach go ever restaurant bar lun...
# 2335  rainbow beach must go look rainbow beach jomti...
# 2336  beautiful building come animal rowing boat san...
# 2337  awful absolutely terrible run absolute rip ple...
#
#                                    score_RoBERTa  intensity_RoBERTa  \
# 0        [0.000545775, 0.0006527193, 0.99880147]              0.998
# 1      [0.00043520975, 0.0006707744, 0.99889404]              0.998
# 2       [0.00041371837, 0.0007984634, 0.9987878]              0.998
# 3      [0.00044122155, 0.0008386694, 0.99872017]              0.998
# 4       [0.0005455051, 0.00066375395, 0.9987908]              0.998
# ...                                          ...                ...
# 2333     [0.00052692054, 0.000617436, 0.9988556]              0.998
# 2334    [0.00031094882, 0.0017167189, 0.9979723]              0.998
# 2335  [0.00043922983, 0.00066251185, 0.99889827]              0.998
# 2336   [0.00027121327, 0.0014958514, 0.99823296]              0.998
# 2337       [0.9685624, 0.028818455, 0.002619132]             -0.966
#
#      resultRoBERTa  rating     date travel_type   location
# 0         Positive       5  2025-08     Friends        NaN
# 1         Positive       5  2025-08     Friends      India
# 2         Positive       5  2025-08      Family        NaN
# 3         Positive       5  2025-08     Friends        NaN
# 4         Positive       5  2025-08     Friends        NaN
# ...            ...     ...      ...         ...        ...
# 2333      Positive       5  2023-01      Family  Australia
# 2334      Positive       5  2023-01     Friends     Canada
# 2335      Positive       4  2023-01     Friends         UK
# 2336      Positive       3  2023-01         NaN    Denmark
# 2337      Negative       1  2023-01     Couples        NaN
#
# [2338 rows x 8 columns]

# %%
df_pattaya_cleaned.to_csv('pattaya_sentiment_1.csv', index=False)

# %% [markdown]
# # **Sentiment Analysis**

# %% [markdown]
# **HANOI Sentiment Analysis**

# %%
# Load data
df_hanoi = pd.read_csv('clean_hanoi.csv', encoding='utf-8')
df_hanoi_sen = df_hanoi[['processed_text']].dropna()

# Load model
def load_model(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    return tokenizer, model

# Compute sentiment probabilities
def sentiment_score(text, tokenizer, model):
    tokens = tokenizer(text, truncation=True, padding=True, max_length=512, return_tensors="pt")
    with torch.no_grad():
        logits = model(**tokens).logits
    return softmax(logits.numpy()[0])  # Returns [negative, neutral, positive]

# Convert probabilities to weighted sentiment intensity score
def intensity_score(probs):
    weights = [-1, 0, 1]  # Corresponding to [negative, neutral, positive]
    return round(sum(p * w for p, w in zip(probs, weights)), 3)

# Run sentiment analysis
models = {
    "RoBERTa": "cardiffnlp/twitter-roberta-base-sentiment"
}

for model_name, model_path in models.items():
    print(f"\nUsing model: {model_name}")
    tokenizer, model = load_model(model_path)

    # Apply sentiment scoring
    df_hanoi_sen['score_' + model_name] = df_hanoi_sen['processed_text'].apply(
        lambda x: sentiment_score(x, tokenizer, model)
    )

    # Apply intensity scoring
    df_hanoi_sen['intensity_' + model_name] = df_hanoi_sen['score_' + model_name].apply(intensity_score)
# Out:
# Using model: RoBERTa
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `RobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
# convert scoreRoBERTa and scoreDistilBERT column into 2 other columns
df_hanoi_sen['resultRoBERTa'] = df_hanoi_sen['score_RoBERTa'].apply(lambda x: x.argmax())

# scoreRoBERTa will be resultRoBERTa with the max value being negative, neutral and positive according to their position
df_hanoi_sen['resultRoBERTa'] = df_hanoi_sen['resultRoBERTa'].replace({0: 'Negative', 1: 'Neutral', 2: 'Positive'})

df_hanoi_sen
# Out:
#                                           processed_text  \
# 0      hà nội really like good food nice people frien...
# 1      great thing hanoi great thing hanoi bella grea...
# 2      great thing hanoi great thing hanoi bella grea...
# 3      teacher bright lot fun food together meal grea...
# 4      teacher bright lot fun food together meal grea...
# ...                                                  ...
# 38797  fantastic couple massage easily best massage v...
# 38798  great hanoi food guide hieu undergrad studying...
# 38799  really good afternoon really nice afternoon ng...
# 38800  best experience hanoi guide thuy amazing one t...
# 38801  wonderful massage beautiful atmosphere staff p...
#
#                                  score_RoBERTa  intensity_RoBERTa  rating  \
# 0        [0.016993705, 0.08790884, 0.89509743]              0.878     4.0
# 1       [0.0022518958, 0.019215526, 0.9785326]              0.976     5.0
# 2       [0.0022518958, 0.019215526, 0.9785326]              0.976     5.0
# 3      [0.0018884634, 0.024878994, 0.97323257]              0.971     5.0
# 4      [0.0018884634, 0.024878994, 0.97323257]              0.971     5.0
# ...                                        ...                ...     ...
# 38797   [0.0019025911, 0.021646915, 0.9764505]              0.975     5.0
# 38798    [0.0041389074, 0.0473428, 0.94851834]              0.944     5.0
# 38799  [0.0014665928, 0.009970934, 0.98856246]              0.987     5.0
# 38800   [0.0020888352, 0.022353826, 0.9755574]              0.973     5.0
# 38801   [0.0025303175, 0.025268808, 0.9722009]              0.970     5.0
#
#           date travel_type   location resultRoBERTa
# 0      2025-07     Friends        NaN      Positive
# 1      2025-07     Couples  Australia      Positive
# 2      2025-07     Couples  Australia      Positive
# 3      2025-07         NaN        NaN      Positive
# 4      2025-07         NaN        NaN      Positive
# ...        ...         ...        ...           ...
# 38797  2023-01     Couples         UK      Positive
# 38798  2023-01      Family  Singapore      Positive
# 38799  2023-01     Couples        NaN      Positive
# 38800  2023-01        Solo        NaN      Positive
# 38801  2023-01     Friends        NaN      Positive
#
# [38802 rows x 8 columns]

# %%
# Merge on 'processed_text'
df_hanoi_cleaned = df_hanoi_sen.merge(
    df_hanoi[['processed_text', 'rating', 'date', 'travel_type', 'location']],  # choose columns to bring in
    on='processed_text',
    how='left'
)
df_hanoi_cleaned

# %%
df_hanoi_cleaned.to_csv('hanoi_sentiment.csv', index=False)

# %% [markdown]
# **DANANG Sentiment Analysis**

# %%
# Load new data
df_danang = pd.read_csv('clean_danang.csv', encoding='utf-8')
df_danang_sen = df_danang[['processed_text']].dropna()

# Apply sentiment scoring
df_danang_sen['score_RoBERTa'] = df_danang_sen['processed_text'].apply(
    lambda x: sentiment_score(x, tokenizer, model)
)

# Apply intensity scoring
df_danang_sen['intensity_RoBERTa'] = df_danang_sen['score_RoBERTa'].apply(intensity_score)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `RobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
# convert scoreRoBERTa column into 2 other columns
df_danang_sen['resultRoBERTa'] = df_danang_sen['score_RoBERTa'].apply(lambda x: x.argmax())

# scoreRoBERTa will be resultRoBERTa with the max value being negative, neutral and positive according to their position
df_danang_sen['resultRoBERTa'] = df_danang_sen['resultRoBERTa'].replace({0: 'Negative', 1: 'Neutral', 2: 'Positive'})

df_danang_sen
# Out:
#                                           processed_text  \
# 0      excellent experience went donk silk tailor jac...
# 1      really deliver ba ri tailor delivered outstand...
# 2      clothes came amazingly super happy staff super...
# 3      tailored clothing came shop recommended friend...
# 4      relaxing experience came without booking récep...
# ...                                                  ...
# 13666  app theatre show important raining bring umbre...
# 13667  visit worth effort step back time visiting imp...
# 13668  rehahn experience came across gallery hochimin...
# 13669  subliming vietnam picture gallery minute walki...
# 13670  great service great service recommend reliable...
#
#                                  score_RoBERTa  intensity_RoBERTa  \
# 0       [0.0035434982, 0.048638206, 0.9478183]              0.944
# 1        [0.008937679, 0.09708384, 0.89397854]              0.885
# 2        [0.002327867, 0.013598603, 0.9840735]              0.982
# 3          [0.010668688, 0.0975591, 0.8917722]              0.881
# 4         [0.002591971, 0.03365725, 0.9637508]              0.961
# ...                                        ...                ...
# 13666    [0.07968553, 0.79999715, 0.120317355]              0.041
# 13667     [0.009126912, 0.18701436, 0.8038587]              0.795
# 13668  [0.0017663914, 0.022590123, 0.97564346]              0.974
# 13669    [0.010314843, 0.15958993, 0.83009523]              0.820
# 13670   [0.0032189835, 0.029617682, 0.9671633]              0.964
#
#       resultRoBERTa
# 0          Positive
# 1          Positive
# 2          Positive
# 3          Positive
# 4          Positive
# ...             ...
# 13666       Neutral
# 13667      Positive
# 13668      Positive
# 13669      Positive
# 13670      Positive
#
# [13671 rows x 4 columns]

# %%
# Merge on 'processed_text'
df_danang_cleaned = df_danang_sen.merge(
    df_danang[['processed_text', 'rating', 'date', 'travel_type', 'location']],  # choose columns to bring in
    on='processed_text',
    how='left'
)
df_danang_cleaned
# Out:
#                                           processed_text  \
# 0      excellent experience went donk silk tailor jac...
# 1      really deliver ba ri tailor delivered outstand...
# 2      clothes came amazingly super happy staff super...
# 3      tailored clothing came shop recommended friend...
# 4      relaxing experience came without booking récep...
# ...                                                  ...
# 13670  app theatre show important raining bring umbre...
# 13671  visit worth effort step back time visiting imp...
# 13672  rehahn experience came across gallery hochimin...
# 13673  subliming vietnam picture gallery minute walki...
# 13674  great service great service recommend reliable...
#
#                                  score_RoBERTa  intensity_RoBERTa  \
# 0       [0.0035434982, 0.048638206, 0.9478183]              0.944
# 1        [0.008937679, 0.09708384, 0.89397854]              0.885
# 2        [0.002327867, 0.013598603, 0.9840735]              0.982
# 3          [0.010668688, 0.0975591, 0.8917722]              0.881
# 4         [0.002591971, 0.03365725, 0.9637508]              0.961
# ...                                        ...                ...
# 13670    [0.07968553, 0.79999715, 0.120317355]              0.041
# 13671     [0.009126912, 0.18701436, 0.8038587]              0.795
# 13672  [0.0017663914, 0.022590123, 0.97564346]              0.974
# 13673    [0.010314843, 0.15958993, 0.83009523]              0.820
# 13674   [0.0032189835, 0.029617682, 0.9671633]              0.964
#
#       resultRoBERTa  rating     date travel_type   location
# 0          Positive       5  2025-08        Solo        NaN
# 1          Positive       5  2025-08        Solo         CA
# 2          Positive       5  2025-08      Family        NaN
# 3          Positive       5  2025-08      Family        NaN
# 4          Positive       5  2025-08     Couples        NaN
# ...             ...     ...      ...         ...        ...
# 13670       Neutral       4  2023-01     Friends  Australia
# 13671      Positive       4  2023-01        Solo  Australia
# 13672      Positive       5  2023-01     Couples        NaN
# 13673      Positive       5  2023-01      Family        NaN
# 13674      Positive       5  2023-01     Couples         UK
#
# [13675 rows x 8 columns]

# %%
df_danang_cleaned.to_csv('danang_sentiment.csv', index=False)

# %% [markdown]
# **BANGKOK Sentiment Analysis**

# %%
# Load new data
df_bangkok = pd.read_csv('clean_bangkok.csv', encoding='utf-8')
df_bangkok_sen = df_bangkok[['processed_text']].dropna()

# Apply sentiment scoring
df_bangkok_sen['score_RoBERTa'] = df_bangkok_sen['processed_text'].apply(
    lambda x: sentiment_score(x, tokenizer, model)
)

# Apply intensity scoring
df_bangkok_sen['intensity_RoBERTa'] = df_bangkok_sen['score_RoBERTa'].apply(intensity_score)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `RobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
# convert scoreRoBERTa column into 2 other columns
df_bangkok_sen['resultRoBERTa'] = df_bangkok_sen['score_RoBERTa'].apply(lambda x: x.argmax())

# scoreRoBERTa will be resultRoBERTa with the max value being negative, neutral and positive according to their position
df_bangkok_sen['resultRoBERTa'] = df_bangkok_sen['resultRoBERTa'].replace({0: 'Negative', 1: 'Neutral', 2: 'Positive'})

df_bangkok_sen
# Out:
#                                           processed_text  \
# 0      great tour anna great tour guide alot fun saw ...
# 1      boat tour excellent excursion fun ken attentiv...
# 2      thon buri canal trip great insight thon buri c...
# 3      great tour great guide showed u lot interestin...
# 4      must great experience would definitely guide f...
# ...                                                  ...
# 14509  high end shopping mall opposite hotel staying ...
# 14510  overwhelmingly good mall architectural wonder ...
# 14511  worth visiting took green flag boat wat arun p...
# 14512  huge shopping mall huge shopping mall lot food...
# 14513  trip amazing sara amazing really took care u c...
#
#                                  score_RoBERTa  intensity_RoBERTa  \
# 0       [0.0018257378, 0.013423596, 0.9847506]              0.983
# 1        [0.002018995, 0.022882884, 0.9750981]              0.973
# 2       [0.002734813, 0.041992098, 0.95527303]              0.953
# 3        [0.0029229203, 0.02523496, 0.9718421]              0.969
# 4      [0.0028189837, 0.027880639, 0.96930045]              0.966
# ...                                        ...                ...
# 14509    [0.009450286, 0.111303054, 0.8792466]              0.870
# 14510     [0.0078194225, 0.06344658, 0.928734]              0.921
# 14511  [0.0018982462, 0.056462947, 0.94163877]              0.940
# 14512     [0.009233985, 0.7506472, 0.24011883]              0.231
# 14513     [0.001752039, 0.0101901, 0.98805785]              0.986
#
#       resultRoBERTa
# 0          Positive
# 1          Positive
# 2          Positive
# 3          Positive
# 4          Positive
# ...             ...
# 14509      Positive
# 14510      Positive
# 14511      Positive
# 14512       Neutral
# 14513      Positive
#
# [14513 rows x 4 columns]

# %%
# Merge on 'processed_text'
df_bangkok_cleaned = df_bangkok_sen.merge(
    df_bangkok[['processed_text', 'rating', 'date', 'travel_type', 'location']],  # choose columns to bring in
    on='processed_text',
    how='left'
)
df_bangkok_cleaned
# Out:
#                                           processed_text  \
# 0      great tour anna great tour guide alot fun saw ...
# 1      boat tour excellent excursion fun ken attentiv...
# 2      thon buri canal trip great insight thon buri c...
# 3      great tour great guide showed u lot interestin...
# 4      must great experience would definitely guide f...
# ...                                                  ...
# 14858  high end shopping mall opposite hotel staying ...
# 14859  overwhelmingly good mall architectural wonder ...
# 14860  worth visiting took green flag boat wat arun p...
# 14861  huge shopping mall huge shopping mall lot food...
# 14862  trip amazing sara amazing really took care u c...
#
#                                  score_RoBERTa  intensity_RoBERTa  \
# 0       [0.0018257378, 0.013423596, 0.9847506]              0.983
# 1        [0.002018995, 0.022882884, 0.9750981]              0.973
# 2       [0.002734813, 0.041992098, 0.95527303]              0.953
# 3        [0.0029229203, 0.02523496, 0.9718421]              0.969
# 4      [0.0028189837, 0.027880639, 0.96930045]              0.966
# ...                                        ...                ...
# 14858    [0.009450286, 0.111303054, 0.8792466]              0.870
# 14859     [0.0078194225, 0.06344658, 0.928734]              0.921
# 14860  [0.0018982462, 0.056462947, 0.94163877]              0.940
# 14861     [0.009233985, 0.7506472, 0.24011883]              0.231
# 14862     [0.001752039, 0.0101901, 0.98805785]              0.986
#
#       resultRoBERTa  rating     date travel_type   location
# 0          Positive       5  2025-07     Couples        NaN
# 1          Positive       5  2025-07      Family        NaN
# 2          Positive       5  2025-07      Family        NaN
# 3          Positive       5  2025-07     Friends        NaN
# 4          Positive       5  2025-07        Solo        NaN
# ...             ...     ...      ...         ...        ...
# 14858      Positive       4  2023-01     Couples     France
# 14859      Positive       5  2023-01     Couples        NaN
# 14860      Positive       5  2023-01         NaN  Singapore
# 14861       Neutral       5  2023-01      Family      China
# 14862      Positive       5  2023-01     Friends        NaN
#
# [14863 rows x 8 columns]

# %%
df_bangkok_cleaned.to_csv('bangkok_sentiment.csv', index=False)

# %% [markdown]
# **PATTAYA Sentiment Analysis**

# %%
# Load new data
df_pattaya = pd.read_csv('clean_pattaya.csv', encoding='utf-8')
df_pattaya_sen = df_pattaya[['processed_text']].dropna()

# Apply sentiment scoring
df_pattaya_sen['score_RoBERTa'] = df_pattaya_sen['processed_text'].apply(
    lambda x: sentiment_score(x, tokenizer, model)
)

# Apply intensity scoring
df_pattaya_sen['intensity_RoBERTa'] = df_pattaya_sen['score_RoBERTa'].apply(intensity_score)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `RobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
# convert scoreRoBERTa column into 2 other columns
df_pattaya_sen['resultRoBERTa'] = df_pattaya_sen['score_RoBERTa'].apply(lambda x: x.argmax())

# scoreRoBERTa will be resultRoBERTa with the max value being negative, neutral and positive according to their position
df_pattaya_sen['resultRoBERTa'] = df_pattaya_sen['resultRoBERTa'].replace({0: 'Negative', 1: 'Neutral', 2: 'Positive'})

df_pattaya_sen
# Out:
#                                          processed_text  \
# 0     best massage existence absolutely fabulous mas...
# 1     great place gem gallery pattaya amazing place ...
# 2     recommend place beautiful organized people wor...
# 3     life altering massage experience absolutely in...
# 4     finally relaxed rejuvenated friend got massage...
# ...                                                 ...
# 2333  great day well run water park start finish wen...
# 2334  awesome beach beach go ever restaurant bar lun...
# 2335  rainbow beach must go look rainbow beach jomti...
# 2336  beautiful building come animal rowing boat san...
# 2337  awful absolutely terrible run absolute rip ple...
#
#                                score_RoBERTa  intensity_RoBERTa resultRoBERTa
# 0     [0.0072626476, 0.050901104, 0.9418363]              0.935      Positive
# 1     [0.0029863047, 0.034561317, 0.9624524]              0.959      Positive
# 2      [0.0049539725, 0.07577563, 0.9192704]              0.914      Positive
# 3      [0.014548055, 0.12608872, 0.85936326]              0.845      Positive
# 4     [0.0035248916, 0.031173743, 0.9653014]              0.962      Positive
# ...                                      ...                ...           ...
# 2333   [0.0024267584, 0.01431447, 0.9832587]              0.981      Positive
# 2334   [0.0027717587, 0.13596162, 0.8612667]              0.858      Positive
# 2335  [0.0026613665, 0.031255536, 0.9660831]              0.963      Positive
# 2336   [0.009857115, 0.121590525, 0.8685523]              0.859      Positive
# 2337   [0.9550377, 0.04089204, 0.0040702284]             -0.951      Negative
#
# [2338 rows x 4 columns]

# %%
# Merge on 'processed_text'
df_pattaya_cleaned = df_pattaya_sen.merge(
    df_pattaya[['processed_text', 'rating', 'date', 'travel_type', 'location']],  # choose columns to bring in
    on='processed_text',
    how='left'
)
df_pattaya_cleaned
# Out:
#                                          processed_text  \
# 0     best massage existence absolutely fabulous mas...
# 1     great place gem gallery pattaya amazing place ...
# 2     recommend place beautiful organized people wor...
# 3     life altering massage experience absolutely in...
# 4     finally relaxed rejuvenated friend got massage...
# ...                                                 ...
# 2333  great day well run water park start finish wen...
# 2334  awesome beach beach go ever restaurant bar lun...
# 2335  rainbow beach must go look rainbow beach jomti...
# 2336  beautiful building come animal rowing boat san...
# 2337  awful absolutely terrible run absolute rip ple...
#
#                                score_RoBERTa  intensity_RoBERTa resultRoBERTa  \
# 0     [0.0072626476, 0.050901104, 0.9418363]              0.935      Positive
# 1     [0.0029863047, 0.034561317, 0.9624524]              0.959      Positive
# 2      [0.0049539725, 0.07577563, 0.9192704]              0.914      Positive
# 3      [0.014548055, 0.12608872, 0.85936326]              0.845      Positive
# 4     [0.0035248916, 0.031173743, 0.9653014]              0.962      Positive
# ...                                      ...                ...           ...
# 2333   [0.0024267584, 0.01431447, 0.9832587]              0.981      Positive
# 2334   [0.0027717587, 0.13596162, 0.8612667]              0.858      Positive
# 2335  [0.0026613665, 0.031255536, 0.9660831]              0.963      Positive
# 2336   [0.009857115, 0.121590525, 0.8685523]              0.859      Positive
# 2337   [0.9550377, 0.04089204, 0.0040702284]             -0.951      Negative
#
#       rating     date travel_type   location
# 0          5  2025-08     Friends        NaN
# 1          5  2025-08     Friends      India
# 2          5  2025-08      Family        NaN
# 3          5  2025-08     Friends        NaN
# 4          5  2025-08     Friends        NaN
# ...      ...      ...         ...        ...
# 2333       5  2023-01      Family  Australia
# 2334       5  2023-01     Friends     Canada
# 2335       4  2023-01     Friends         UK
# 2336       3  2023-01         NaN    Denmark
# 2337       1  2023-01     Couples        NaN
#
# [2338 rows x 8 columns]

# %%
df_pattaya_cleaned.to_csv('pattaya_sentiment.csv', index=False)
